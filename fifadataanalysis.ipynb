# %% [markdown]
# <a href="https://colab.research.google.com/github/VGNANDHINI/fifa-player-analytics-project/blob/main/fifadataanalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')


file_path = '/content/drive/My Drive/players_20.csv' # Placeholder path
fifa = pd.read_csv(file_path)
display(fifa.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
# ...

# %%
for col in fifa.columns:
  print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['club'].value_counts()
# Out:
# club
# Wolverhampton Wanderers    33
# West Ham United            33
# Lazio                      33
# RB Leipzig                 33
# RC Celta                   33
#                            ..
# Turkey                      1
# Mexico                      1
# GIF Sundsvall               1
# Seongnam FC                 1
# Śląsk Wrocław               1
# Name: count, Length: 698, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
plt.figure(figsize=(10, 6))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()),list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.show()

# %%
salaryofppl=fifa[['short_name','wage_eur']]
salaryofppl.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
salaryofppl=salaryofppl.sort_values(by='wage_eur',ascending=False)
salaryofppl.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,8))
plt.bar(list(salaryofppl['short_name'])[0:5],list(salaryofppl['wage_eur'])[0:5],color='r')
plt.show()

# %%
argentina=fifa[fifa['nationality']=='Argentina']
argentina.head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
# 93     201399  https://sofifa.com/player/201399/mauro-icardi/...    M. Icardi
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 17  Sergio Leonel Agüero del Castillo   31  1988-06-02        173         70
# 23        Paulo Bruno Exequiel Dybala   25  1993-11-15        177         75
# 66    Ángel Fabián Di María Hernández   31  1988-02-14        180         69
# 93        Mauro Emanuel Icardi Rivero   26  1993-02-19        181         75
#
# ...

# %%
argentina[['short_name','wage_eur']].sort_values(by='wage_eur',ascending=False).head()
# Out:
#      short_name  wage_eur
# 0      L. Messi    565000
# 17    S. Agüero    300000
# 23    P. Dybala    215000
# 98   G. Higuaín    175000
# 66  A. Di María    150000

# %%
argentina['height_cm'].sort_values(ascending=False).head()
# Out:
# 6067    197
# 6542    197
# 1786    196
# 519     195
# 1141    195
# Name: height_cm, dtype: int64

# %%
argentina.sort_values(by='wage_eur',ascending=False).head()
# Out:
#     sofifa_id                                         player_url   short_name  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...     L. Messi
# 17     153079  https://sofifa.com/player/153079/sergio-aguero...    S. Agüero
# 23     211110  https://sofifa.com/player/211110/paulo-dybala/...    P. Dybala
# 98     167664  https://sofifa.com/player/167664/gonzalo-higua...   G. Higuaín
# 66     183898  https://sofifa.com/player/183898/angel-di-mari...  A. Di María
#
#                             long_name  age         dob  height_cm  weight_kg  \
# 0      Lionel Andrés Messi Cuccittini   32  1987-06-24        170         72
# 17  Sergio Leonel Agüero del Castillo   31  1988-06-02        173         70
# 23        Paulo Bruno Exequiel Dybala   25  1993-11-15        177         75
# 98            Gonzalo Gerardo Higuaín   31  1987-12-10        186         89
# 66    Ángel Fabián Di María Hernández   31  1988-02-14        180         69
#
# ...

# %%
argentina.sort_values(by='height_cm',ascending=False).head()
# Out:
#       sofifa_id                                         player_url  \
# 6067     222889  https://sofifa.com/player/222889/lucas-acevedo...
# 6542     223071  https://sofifa.com/player/223071/fernando-pell...
# 1786     205186  https://sofifa.com/player/205186/paulo-gazzani...
# 519      179847  https://sofifa.com/player/179847/federico-fazi...
# 1141     152993  https://sofifa.com/player/152993/renato-civell...
#
#          short_name              long_name  age         dob  height_cm  \
# 6067     L. Acevedo          Lucas Acevedo   27  1991-11-08        197
# 6542  F. Pellegrino    Fernando Pellegrino   33  1986-03-31        197
# 1786   P. Gazzaniga   Paulo Dino Gazzaniga   27  1992-01-02        196
# 519        F. Fazio  Federico Julián Fazio   32  1987-03-17        195
# 1141     R. Civelli         Renato Civelli   35  1983-10-14        195
#
#       weight_kg nationality                    club  ...   lwb   ldm   cdm  \
# ...

# %%
player_shooting =fifa[['short_name','shooting']]
player_shooting.sort_values(by='shooting',ascending=True).head()
# Out:
#           short_name  shooting
# 4330   F. Ceccherini      15.0
# 11455  A. Camigliano      16.0
# 16661     L. Polvani      16.0
# 3695      D. Maietta      16.0
# 12793     N. Canavan      16.0

# %%
player_defending=fifa[['short_name','defending','nationality','club']]
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 16  G. Chiellini       90.0        Italy           Juventus
# 49    M. Hummels       89.0      Germany  Borussia Dortmund
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter

# %%
liver_pool=fifa[fifa['club']=='Liverpool']
liver_pool.head()
# Out:
#     sofifa_id                                         player_url  \
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 39     208722  https://sofifa.com/player/208722/sadio-mane/20...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
#
#          short_name                            long_name  age         dob  \
# 7       V. van Dijk                      Virgil van Dijk   27  1991-07-08
# 9          M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
# 39          S. Mané                           Sadio Mané   27  1992-04-10
# 63  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
#
#     height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
liver_pool.sort_values(by='wage_eur',ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 9      209331  https://sofifa.com/player/209331/mohamed-salah...
# 39     208722  https://sofifa.com/player/208722/sadio-mane/20...
# 7      203376  https://sofifa.com/player/203376/virgil-van-di...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
#
#          short_name                            long_name  age         dob  \
# 9          M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 39          S. Mané                           Sadio Mané   27  1992-04-10
# 7       V. van Dijk                      Virgil van Dijk   27  1991-07-08
# 63  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
#
#     height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
liver_pool.sort_values(by='shooting',ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 9       209331  https://sofifa.com/player/209331/mohamed-salah...
# 39      208722  https://sofifa.com/player/208722/sadio-mane/20...
# 63      201942  https://sofifa.com/player/201942/roberto-firmi...
# 313     193348  https://sofifa.com/player/193348/xherdan-shaqi...
# 788     213135  https://sofifa.com/player/213135/divock-origi/...
#
#           short_name                            long_name  age         dob  \
# 9           M. Salah                 Mohamed  Salah Ghaly   27  1992-06-15
# 39           S. Mané                           Sadio Mané   27  1992-04-10
# 63   Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
# 313       X. Shaqiri                      Xherdan Shaqiri   27  1991-10-10
# 788         D. Origi                         Divock Origi   24  1995-04-18
#
#      height_cm  weight_kg  nationality       club  ...   lwb   ldm   cdm  \
# ...
